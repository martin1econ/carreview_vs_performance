# %%
#necessary libraries 

import pandas as pd
import numpy as np
import matplotlib as mpl
import seaborn as sns
import matplotlib.pyplot as plt

# %%
## Instead of having two different dataframes (one for customer and other for expert reviews)
## I can combine both into one and just have a category column separating them

# %%
## * parse_dates = ['date'] as argument for read csv
## * create a function to repeatedly plot different makes ratings vs stock with the same set up 
## Also, you can automate the creation of graphs using a loop
##sns has hue parameter that allows to add additional dimension through color

## Saved with first column as index so add index_col=[0]

stocks = pd.read_csv('cleaned_data/date_symbol_open1.csv',index_col=[0])
stocks[stocks['Symbol']=='F'].head()
# Out:
#           Date Symbol   Open
# 1   2009-12-31      F  10.04
# 9   2010-01-04      F  10.17
# 33  2010-01-05      F  10.45
# 57  2010-01-06      F  11.21
# 81  2010-01-07      F  11.46

# %%
cust_reviews = pd.read_csv('cleaned_data/review_x_symbol1.csv',index_col=[0])
cust_reviews['Reviewed_by'] = 'customer'
cust_reviews[cust_reviews['Company']=='toyota'].head()
# Out:
#        Company    Model  Year         Date  Rating Symbol Reviewed_by
# 251587  toyota  4runner  2000   01/31/2014       4     TM    customer
# 251588  toyota  4runner  2000   10/24/2014       4     TM    customer
# 251589  toyota  4runner  2000   08/12/2012       4     TM    customer
# 251590  toyota  4runner  2000   11/15/2010       4     TM    customer
# 251591  toyota  4runner  2000   04/15/2015       4     TM    customer

# %%
expert_reviews = pd.read_csv('cleaned_data/symbol_year_expert1.csv',index_col=[0])
expert_reviews['Reviewed_by'] = 'expert'
expert_reviews.head()
# Out:
#   Company model  Year  Expert_rating Symbol Reviewed_by
# 0   acura   ILX  2017            7.2    HMC      expert
# 1   acura   RDX  2020            8.1    HMC      expert
# 2   acura   MDX  2020            8.2    HMC      expert
# 3   acura   ILX  2020            7.3    HMC      expert
# 4   acura   ILX  2018            7.3    HMC      expert

# %%
#expert reviews does not have a date column, but we can assume that they were reviewed the year of model

expert_reviews.rename(columns={"model": "Model", "Expert_rating": "Rating"},inplace=True)
expert_reviews.columns
# Out:
# Index(['Company', 'Model', 'Year', 'Rating', 'Symbol', 'Reviewed_by'], dtype='object')

# %%
#I have to have only Makes that have both expert and customer reviews in both df's before appending 

makes_tokeep = expert_reviews['Company'].unique()
l=sorted(makes_tokeep)

# %%
#list below matches list above so we can assign it to be the new list of companies for reviews 
k = cust_reviews[cust_reviews['Company'].isin(makes_tokeep)]
m=sorted(k['Company'].unique())
compare = pd.DataFrame({'col1':l,'col2':m})
compare
# Out:
#              col1           col2
# 0           acura          acura
# 1            audi           audi
# 2             bmw            bmw
# 3           buick          buick
# 4        cadillac       cadillac
# 5       chevrolet      chevrolet
# 6            ford           ford
# 7           honda          honda
# 8         hyundai        hyundai
# 9             kia            kia
# 10          lexus          lexus
# 11          mazda          mazda
# 12  mercedes-benz  mercedes-benz
# 13         nissan         nissan
# 14         subaru         subaru
# 15          tesla          tesla
# 16         toyota         toyota
# 17     volkswagen     volkswagen
# 18          volvo          volvo

# %%
#assign k filter above to cust reviews companies
cust_reviews = k
cust_reviews['Company'].unique()
# Out:
# array(['acura', 'audi', 'bmw', 'buick', 'cadillac', 'chevrolet', 'ford',
#        'honda', 'hyundai', 'kia', 'lexus', 'mazda', 'mercedes-benz',
#        'nissan', 'subaru', 'tesla', 'toyota', 'volkswagen', 'volvo'],
#       dtype=object)

# %%
#prepare to just append into each other 
#expert reviews does not have a 'Date' meaning when the review happened so we will assume:
#expert review happened the year of the model of the car 

m_d='01/01/'
new_dates =[]
years = expert_reviews['Year'].astype('str')

for x in years:
    new_dates.append(m_d+x)
new_dates[0:5]    
    
expert_reviews['Date'] = new_dates
expert_reviews.head()
# Out:
#   Company Model  Year  Rating Symbol Reviewed_by        Date
# 0   acura   ILX  2017     7.2    HMC      expert  01/01/2017
# 1   acura   RDX  2020     8.1    HMC      expert  01/01/2020
# 2   acura   MDX  2020     8.2    HMC      expert  01/01/2020
# 3   acura   ILX  2020     7.3    HMC      expert  01/01/2020
# 4   acura   ILX  2018     7.3    HMC      expert  01/01/2018

# %%
# reindexing the columns so that we can just append customer reviews 

expert_reviews = expert_reviews.reindex(columns=['Company', 'Model', 'Year', 'Date', 'Rating', 'Symbol', 'Reviewed_by'])
expert_reviews.head()
# Out:
#   Company Model  Year        Date  Rating Symbol Reviewed_by
# 0   acura   ILX  2017  01/01/2017     7.2    HMC      expert
# 1   acura   RDX  2020  01/01/2020     8.1    HMC      expert
# 2   acura   MDX  2020  01/01/2020     8.2    HMC      expert
# 3   acura   ILX  2020  01/01/2020     7.3    HMC      expert
# 4   acura   ILX  2018  01/01/2018     7.3    HMC      expert

# %%
# multiply reviews for customers times two, so that they are in the same scale 

cust_reviews['Rating'] = cust_reviews['Rating']*2
cust_reviews.head()
# Out:
#   Company Model  Year         Date  Rating Symbol Reviewed_by
# 0   acura   ilx  2013   08/12/2012      10    HMC    customer
# 1   acura   ilx  2013   07/26/2016      10    HMC    customer
# 2   acura   ilx  2013   09/14/2013       8    HMC    customer
# 3   acura   ilx  2013   01/26/2015       8    HMC    customer
# 4   acura   ilx  2013   03/26/2016      10    HMC    customer

# %%
## Instead of having two different dataframes (one for customer and other for expert reviews)
## I can combine both into one and just have a category column separating them
## now we can just append because they have the same format

review = expert_reviews.append(cust_reviews)
review['Company'].unique(),review.head()
# Out:
# (array(['acura', 'audi', 'lexus', 'mercedes-benz', 'bmw', 'buick',
#         'cadillac', 'chevrolet', 'ford', 'honda', 'hyundai', 'kia',
#         'mazda', 'nissan', 'subaru', 'tesla', 'toyota', 'volkswagen',
#         'volvo'], dtype=object),
#    Company Model  Year        Date  Rating Symbol Reviewed_by
#  0   acura   ILX  2017  01/01/2017     7.2    HMC      expert
#  1   acura   RDX  2020  01/01/2020     8.1    HMC      expert
#  2   acura   MDX  2020  01/01/2020     8.2    HMC      expert
#  3   acura   ILX  2020  01/01/2020     7.3    HMC      expert
#  4   acura   ILX  2018  01/01/2018     7.3    HMC      expert)

# %%
#There are two issues with Date column to fix, the format is not datetime and there are invalid dates

review['Date'].value_counts(),review.head()
# Out:
# ( 10/22/2003    322
#   09/06/2003    302
#   01/24/2004    272
#   12/27/2003    262
#   12/03/2003    239
#                ...
#   Texas           1
#   GM!!!           1
#   Powers          1
#  101              1
#   P.E.            1
#  Name: Date, Length: 7211, dtype: int64,
#    Company Model  Year        Date  Rating Symbol Reviewed_by
#  0   acura   ILX  2017  01/01/2017     7.2    HMC      expert
#  1   acura   RDX  2020  01/01/2020     8.1    HMC      expert
#  2   acura   MDX  2020  01/01/2020     8.2    HMC      expert
#  3   acura   ILX  2020  01/01/2020     7.3    HMC      expert
#  4   acura   ILX  2018  01/01/2018     7.3    HMC      expert)

# %%
## make Date column into date format, therea

review["Date"] = pd.to_datetime(review["Date"],errors='coerce')
#review["Date"] = 
review["Date"][review["Reviewed_by"]=='expert'],review["Date"].dtypes


#review.dtypes, review['Date'].max(),review['Date'].min()
# Out:
# (0     2017-01-01
#  1     2020-01-01
#  2     2020-01-01
#  3     2020-01-01
#  4     2018-01-01
#           ...
#  790   2020-01-01
#  791   2020-01-01
#  792   2017-01-01
#  793   2020-01-01
#  794   2015-01-01
#  Name: Date, Length: 795, dtype: datetime64[ns],
#  dtype('<M8[ns]'))

# %%
# the invalid dates have been converted into NaT, which we can drop (all of them from cust_review)
#review = review.dropna()
review.describe(),review.head()
# Out:
# (                Year         Rating
#  count  226865.000000  226865.000000
#  mean     2007.878386       8.002368
#  std         5.428724       1.989355
#  min      2000.000000       2.000000
#  25%      2004.000000       8.000000
#  50%      2007.000000       8.000000
#  75%      2011.000000      10.000000
#  max      2022.000000      10.000000,
#    Company Model  Year       Date  Rating Symbol Reviewed_by
#  0   acura   ILX  2017 2017-01-01     7.2    HMC      expert
#  1   acura   RDX  2020 2020-01-01     8.1    HMC      expert
#  2   acura   MDX  2020 2020-01-01     8.2    HMC      expert
#  3   acura   ILX  2020 2020-01-01     7.3    HMC      expert
#  4   acura   ILX  2018 2018-01-01     7.3    HMC      expert)

# %%
## extract differences between mean score per year per model for customer and expert reviews 


expert = review[review['Reviewed_by']=='expert']
expert_group = expert.groupby(['Company',expert['Date'].dt.year]).mean()
#['Rating']
customer = review[review['Reviewed_by']=='customer']
customer_group = customer.groupby(['Company',customer['Date'].dt.year]).mean()

#Cutting the same date and company slice to compare and see if the diffs seem correct

diff = expert_group-customer_group
expert_group.iloc[0:5,1],customer_group.iloc[8:13,1],diff.iloc[8:13,1]
# Out:
# (Company  Date
#  acura    2010    8.4
#           2011    8.5
#           2012    8.4
#           2013    7.8
#           2014    7.9
#  Name: Rating, dtype: float64,
#  Company  Date
#  acura    2010.0    8.038835
#           2011.0    7.915493
#           2012.0    7.786517
#           2013.0    7.850340
#           2014.0    7.821429
#  Name: Rating, dtype: float64,
#  Company  Date
#  acura    2010.0    0.361165
#           2011.0    0.584507
#           2012.0    0.613483
#           2013.0   -0.050340
#           2014.0    0.078571
#  Name: Rating, dtype: float64)

# %%
#rank of biggest differences between expert and customer review 

diff_in_means = diff['Rating'].dropna()
m_dd = diff_in_means.groupby('Company').mean()
m_dd.sort_values(ascending=False)
# Out:
# Company
# chevrolet        1.176573
# ford             0.747278
# nissan           0.565584
# volkswagen       0.515430
# subaru           0.512530
# honda            0.509308
# kia              0.493801
# buick            0.410469
# cadillac         0.353755
# toyota           0.299443
# hyundai          0.238801
# bmw              0.122676
# mazda            0.090323
# audi             0.051023
# mercedes-benz    0.047964
# tesla            0.032120
# volvo            0.031055
# acura            0.029616
# lexus            0.006752
# Name: Rating, dtype: float64

# %%
#change the y axis limits 
#change the order to small to biggest diff

## Are they similar enough to be assesed together?
## big diff between ford chevrolet acura buick expert/customer


sns.set_context("notebook", font_scale=3)
sns.set(rc = {'figure.figsize':(17,6)})
g = sns.barplot(x='Company',y='Rating',data=review,order=list(m_dd.sort_values(ascending=False).index), hue='Reviewed_by')
g.set_ylim([7.25,9])
#plt.legend(fontsize='x-large',bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.xticks(rotation = 60)
plt.show()

# %%
#comparison of expert vs customer reviews avg's
## cust reviews has to be multiplied by two 

##One column has to be categorical and say whether it is expert or customer type review 

#customer = cust_reviews[['Company','Rating']].groupby('Company').mean().apply(lambda x: x*2).sort_values(by='Rating')
#customer['Customer Variance'] = cust_reviews[['Company','Rating']].groupby('Company').var()
#expert = expert_reviews[['Company','Expert_rating']].groupby('Company').mean().sort_values(by='Expert_rating')
#expert['Expert Variance'] = expert_reviews[['Company','Expert_rating']].groupby('Company').var()
#result_review1 = customer.merge(expert, how='left', on ='Company')
#result_review1.dropna(inplace=True)
#result_review1['Diff']= abs(result_review1['Rating']-result_review1['Expert_rating'])
#result_review1 = result_review1.reindex(columns=['Rating','Expert_rating','Diff', 'Customer Variance','Expert Variance'])

#result_review1.sort_values(by='Diff', ascending=False)
symbol_unique = review['Symbol'].unique()
symbol_unique
# Out:
# array(['HMC', 'VOW3.DE', 'TM', 'DAI.DE', 'BMW.DE', 'GM', 'F', 'HYMTF',
#        '000270.KS', '7261.T', '7201.T', '7270.T', 'TSLA', 'VOLCAR-B.ST'],
#       dtype=object)

# %%
## We don't need daily price changes, we just need month to month or even year to year 
stocks['Open'].describe()
# Out:
# count    101126.000000
# mean       2412.369142
# std        9759.656137
# min           0.930000
# 25%          15.290000
# 50%          55.594999
# 75%         644.000000
# max      100500.000000
# Name: Open, dtype: float64

# %%
## Have to make date column date
stocks['Date']= pd.to_datetime(stocks['Date'])
stocks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 101126 entries, 0 to 101125
# Data columns (total 3 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Date    101126 non-null  datetime64[ns]
#  1   Symbol  101126 non-null  object
#  2   Open    101126 non-null  float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 3.1+ MB

# %%
#We only need the symbols from the companies that we have chosen, stored in symbol_unique

## Four stocks are on a different scale than the others, it may be helpful to graoh them separately

stocks = stocks[stocks['Symbol'].isin(symbol_unique)]
stocks.groupby('Symbol').mean().sort_values(by='Open',ascending=False)
# Out:
#                      Open
# Symbol
# 000270.KS    51452.965818
# 7270.T        2502.525159
# 7261.T        1398.957095
# 7201.T         868.197685
# VOW3.DE        149.708166
# TSLA           130.742552
# TM             115.574411
# VOLCAR-B.ST     75.254058
# BMW.DE          73.734601
# DAI.DE          56.524836
# HYMTF           38.856101
# GM              35.198417
# HMC             31.765944
# F               12.476305

# %%
## create a variable that is grouped by symbol and 
#that doesnt include the huge stocks, so we can visualize better

large_stocks = ['7270.T','7261.T','7201.T','000270.KS']
w = stocks[~stocks['Symbol'].isin(large_stocks)]
stock_year = w.groupby([stocks.Symbol,stocks.Date.dt.year]).mean()
stock_year
# Out:
#                     Open
# Symbol  Date
# BMW.DE  2010   42.094727
#         2011   58.677344
#         2012   63.396047
#         2013   74.467381
#         2014   87.804246
# ...                  ...
# VOW3.DE 2018  156.511349
#         2019  153.859602
#         2020  141.416969
#         2021  197.379372
#         2022  185.908461
#
# [123 rows x 1 columns]

# %%
# maybe I can do the precentage change or similar, to bring all stocks into scale \


sns.set_context("notebook", font_scale=2.75)
sns.set(rc = {'figure.figsize':(15,8)})
mpl.rcParams['lines.linewidth'] = 3.5
g = sns.lineplot(x='Date',y='Open',data=stock_year,hue='Symbol',style = 'Symbol', markers=True)
plt.legend(fontsize='x-large',bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
g.set_ylim([0,250])
plt.show()

# %%
## Now, we want to see the change for the reviews over the years

review_year = review[['Symbol','Date','Rating']].groupby([review.Symbol,review.Date.dt.year]).mean()
review_year.head(10)
# Out:
#                     Rating
# Symbol    Date
# 000270.KS 2002.0  7.519553
#           2003.0  7.673716
#           2004.0  8.023426
#           2005.0  8.043956
#           2006.0  7.921659
#           2007.0  7.920286
#           2008.0  7.579559
#           2009.0  7.646201
#           2010.0  7.468465
#           2011.0  7.428647

# %%
#I should create a column with the makes that the symbols represent so that it is easier to graph and undertand 
#probably also better if graph change instead actual rating 

sns.set_context("notebook", font_scale=2.75)
sns.set(rc = {'figure.figsize':(15,8)})
mpl.rcParams['lines.linewidth'] = 3.5
g = sns.lineplot(x='Date',y='Rating',data=review_year,hue='Symbol',style = 'Symbol', markers=True)
plt.legend(fontsize='x-large',bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
g.set_ylim([6,9.6])
plt.show()

# %%
#percent change of stock$ and ratings per make per year 

##ignore year colum.. refers to model YEar

h = review.groupby(['Symbol',review['Date'].dt.year]).mean()
review_delta_perc = h.groupby('Symbol').pct_change()*100
review_delta_perc.fillna(0, inplace=True)
graph_delta_review = review_delta_perc.reset_index()
graph_delta_review.rename(columns={'Rating':'Change_%'}, inplace=True)
graph_delta_review['Date'] = graph_delta_review['Date'].astype('int64')
graph_delta_review.describe()
# Out:
#               Date        Year    Change_%
# count   285.000000  285.000000  285.000000
# mean   2012.185965    0.047916    0.239663
# std       6.048264    0.051810    5.737242
# min    2002.000000   -0.072692  -21.900179
# 25%    2007.000000    0.024674   -2.378758
# 50%    2012.000000    0.040802   -0.183316
# 75%    2017.000000    0.054448    1.935011
# max    2022.000000    0.412765   32.587065

# %%
j = stocks.groupby(['Symbol',stocks['Date'].dt.year]).mean()
stocks_delta_perc = j.groupby('Symbol').pct_change()*100
stocks_delta_perc.fillna(0,inplace= True)
graph_delta_stock = stocks_delta_perc.reset_index()
graph_delta_stock['Symbol'].astype('str')
graph_delta_stock.rename(columns={'Open':'Change_%'}, inplace=True)
graph_delta_stock.describe()
#graph_stock.dtypes
# Out:
#               Date    Change_%
# count   175.000000  175.000000
# mean   2015.902857   13.702889
# std       3.881394   51.653944
# min    2009.000000  -43.673968
# 25%    2013.000000   -9.890407
# 50%    2016.000000    0.000000
# 75%    2019.000000   18.104077
# max    2022.000000  429.448052

# %%
## above you have delta for reviews and stocks 
sns.set_context("notebook", font_scale=4.75)
sns.set_theme(style="whitegrid", palette="pastel")

# Plot the lines on two facets
sns.relplot(
    data=graph_delta_stock,
    x="Date", y="Change_%",
    hue="Symbol", style="Symbol", col="Symbol",col_wrap=2,
    kind="line",
    height=5, aspect=2, facet_kws=dict(sharex=False),linewidth=5
)
plt.ylim([-50,180])
#sns.lmplot(x="Date", y="Change_%", col="Symbol", hue="Symbol", data=graph_review,
 #          col_wrap=3, ci=None,palette="dark", height=4,
  #         scatter_kws={"s": 50, "alpha": 1})


# Show the results of a linear regression within each dataset
#sns.lmplot(x="Date", y="Change_%", col="Symbol", hue="Symbol", data=graph_stock,
 #          col_wrap=3, ci=None, palette="muted", height=4,
  #         scatter_kws={"s": 50, "alpha": 1})

plt.show()

# %%
graph_delta_review['Date'] = graph_delta_review['Date'].astype('int64')

# %%
graph_delta_review.head(2)
# Out:
#       Symbol  Date      Year  Change_%
# 0  000270.KS  2002  0.000000  0.000000
# 1  000270.KS  2003  0.048068  2.050161

# %%
graph_delta_stock.head(2)
# Out:
#       Symbol  Date    Change_%
# 0  000270.KS  2010    0.000000
# 1  000270.KS  2011  111.462931

# %%
#We are going to make a symbol date column so that we can get rid of the years that dont match 
# dont match in the sense that reviews has 2002 sometimes, and expert reviews doesn't 

#corr_perc_review = graph_delta_review[['Symbol','Date','Change_%']]
#corr_perc_stock = graph_delta_stock


#corr_perc_review['make_date'] = graph_delta_review['Symbol'] + str(graph_delta_review['Date'])
#corr_perc_stock['make_date'] = graph_delta_stock['Symbol'] + str(graph_delta_stock['Date'])

#corr_perc_review.head()
#corr_perc_stock.head()

#corr_perc_review.drop(columns=['Symbol','Date'])
#corr_perc_stock.drop(columns=['Symbol','Date'])
# Out:
#       Symbol  Date    Change_%  \
# 0  000270.KS  2010    0.000000
# 1  000270.KS  2011  111.462931
# 2  000270.KS  2012    3.610931
# 3  000270.KS  2013  -18.369490
# 4  000270.KS  2014   -3.578174
#
#                                            make_date
# 0  000270.KS0      2010\n1      2011\n2      2012...
# 1  000270.KS0      2010\n1      2011\n2      2012...
# 2  000270.KS0      2010\n1      2011\n2      2012...
# 3  000270.KS0      2010\n1      2011\n2      2012...
# 4  000270.KS0      2010\n1      2011\n2      2012...

# %%
#np.corrcoef(x,y)
#np.polyfit()
